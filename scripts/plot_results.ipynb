# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv(r'C:\Users\lhauptmann\Code\WristPPG2\scripts\sensor_experiment.csv')
#df = df.groupby("Name")["val/f1_score_macro"].agg([np.mean, np.std])

# %%
df["Sensor"] = df["Name"].map(lambda x: x.split("_")[1])
df["Modality"] = df["Name"].map(lambda x: x.split("_")[2] if len(x.split("_")) > 2 else "ALL")

# %%
df["Modality"] = df["Modality"].map({"ppg": "PPG", "acc": "ACC", "ALL": "PPG + ACC"})
df["Sensor"] = df["Sensor"].map({"ppggreenamb": "Green & Ambient", "ppggreenir": "Green & IR", "ppggreenred": "Green & Red", "ppgsmall": "Original Case Green & IR", "ppgloose":"Loose Sensor Green & Red"})

# %%
sns.barplot(data=df, x="Sensor", y="val/f1_score_macro", hue="Modality")
# rotate x labels
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Green & Ambient'),
#   Text(1, 0, 'Green & Red'),
#   Text(2, 0, 'Original Case Green & IR'),
#   Text(3, 0, 'Green & IR'),
#   Text(4, 0, 'Loose Sensor Green & Red')])

# %%
df
# Out:
#                                 mean       std       Sensor Modality
# Name
# supervised_ppggreenamb      0.867580  0.146045  ppggreenamb      ALL
# supervised_ppggreenamb_acc  0.936586  0.046754  ppggreenamb      acc
# supervised_ppggreenamb_ppg  0.567298  0.134113  ppggreenamb      ppg
# supervised_ppggreenir       0.689817  0.017343   ppggreenir      ALL
# supervised_ppggreenir_acc   0.700627  0.123957   ppggreenir      acc
# supervised_ppggreenir_ppg   0.367405  0.062322   ppggreenir      ppg
# supervised_ppggreenred      0.828646  0.094045  ppggreenred      ALL
# supervised_ppggreenred_acc  0.871939  0.149556  ppggreenred      acc
# supervised_ppggreenred_ppg  0.445499  0.043679  ppggreenred      ppg
# supervised_ppgloose         0.544065  0.170767     ppgloose      ALL
# supervised_ppgsmall         0.775923  0.117337     ppgsmall      ALL
# supervised_ppgsmall_acc     0.860567  0.078149     ppgsmall      acc
# ...
