# %%
import os
import numpy as np
import pandas as pd
import h5py

# %%
def import_hdf5_sequences(file_path,):
    sample = {}
    with h5py.File(file_path, 'r') as f:
        
        data_dict = f["data"]
        for key in data_dict:
            sample[key] = data_dict[key][:]  
                    
        sample["participant"] = os.path.basename(file_path).split("_")[1]
        sample["session"] = os.path.basename(file_path).split("_")[2].replace(".hdf5", "")
        sample["label"] = [el.split("_")[0] for el in f.keys() if el != "data"]
        sample["label_times"] = [(f[key]["start_time"][()], f[key]["end_time"][()]) for key in f.keys() if key != "data"]
        sample["label_indices"] = [(f[key]["start_index"][()], f[key]["end_index"][()]) for key in f.keys() if key != "data"]
        sample["timestamp"] = [el.split("_")[1] for el in f.keys() if el != "data"]
    return sample

def save_hd5f_sequence(file_path, sample, overwrite=False):
    if not overwrite:
        assert not os.path.exists(file_path), "File already exists"
    with h5py.File(file_path, 'w') as f:
        data_dict = f.create_group("data")
        for key in sample:
            if key == "participant" or key == "session" or key == "label" or key == "label_times" or key == "label_indices" or key == "timestamp":
                continue
            data_dict.create_dataset(key, data=sample[key])
        for i, label in enumerate(sample["label"]):
            label_group = f.create_group(label + "_{}".format(sample["timestamp"][i]))
            label_group.create_dataset("start_time", data=sample["label_times"][i][0])
            label_group.create_dataset("end_time", data=sample["label_times"][i][1])
            label_group.create_dataset("start_index", data=sample["label_indices"][i][0])
            label_group.create_dataset("end_index", data=sample["label_indices"][i][1])
            label_group.create_dataset("label", data=label)
            
    print("Saved to {}".format(file_path))
    
def add_neg_labels(session):

    longest_label_list = np.argsort([el[1] - el[0] for el in session["label_indices"]])[::-1]
    longest_label = session["label_indices"][longest_label_list[0]]
    if longest_label[1] - longest_label[0] > 500 and session["label"][longest_label_list[0]] == "o":
        neg_start_time = session["label_times"][longest_label_list[0]][0]
        neg_end_time = session["label_times"][longest_label_list[0]][1]
        neg_start_index = session["label_indices"][longest_label_list[0]][0]
        neg_end_index = session["label_indices"][longest_label_list[0]][1]
        session["label"].pop(longest_label_list[0])
        session["label_indices"].pop(longest_label_list[0])
        session["label_times"].pop(longest_label_list[0])
    else:
        labels_time_sorted = np.argsort([el[0] for el in session["label_indices"]])
        
        neg_start_time = np.array(session["label_times"])[labels_time_sorted[-2]][1]
        neg_end_time = np.array(session["label_times"])[labels_time_sorted[-1]][0]
        neg_start_index = np.array(session["label_indices"])[labels_time_sorted[-2]][1]
        neg_end_index = np.array(session["label_indices"])[labels_time_sorted[-1]][0]
        if neg_end_index  - neg_start_index > 500:
            return session
        
    sampling_rate_ppg = 112.3
    window_size, step_size = 180, 100
    time_window_size = window_size / sampling_rate_ppg
    s_indices = np.arange(neg_start_index, neg_end_index - window_size, step_size)
    s_times = np.linspace(neg_start_time, neg_end_time - time_window_size, len(s_indices))
    
    i = 0
    for s_index, s_time in zip(s_indices, s_times): 
        e_index = s_index + window_size
        e_time = s_time + time_window_size

        if e_index > len(session["acc_x"]):
            print(e_index)
            continue
        i = i + 1
        session["label_indices"].append((s_index, e_index))
        session["label_times"].append((s_time, e_time))
        session["label"].append("o")
        session["timestamp"].append(int(s_time*1000))
    print(f"Added {i} empty labels")
    return session

# %%
data_path = r"C:\Users\lhauptmann\Code\WristPPG2\data\dataset"

for participant_folder in os.listdir(data_path):
    
    participant_folder_path = os.path.join(data_path, participant_folder)
    if not os.path.isdir(participant_folder_path):
        continue
    for session_file in os.listdir(participant_folder_path):
        if not session_file.endswith(".hdf5"):
            continue
        print(session_file)
        session_file_path = os.path.join(participant_folder_path, session_file)
        session = import_hdf5_sequences(session_file_path)
        assert len(session["label_indices"]) == len(session["label_times"]) == len(session["label"])
        session = add_neg_labels(session)
        assert len(session["label_indices"]) == len(session["label_times"]) == len(session["label"])
        save_path_session = session_file_path.replace("dataset", "dataset_corr")
        os.makedirs(os.path.split(save_path_session)[0], exist_ok=True)
        save_hd5f_sequence(save_path_session, session, overwrite=False)

# %%
session_indices = np.argsort([el[0] for el in session["label_indices"]])[::-1]
print(np.array(session["label_indices"])[session_indices[:5]])
print(np.array(session["label"])[session_indices[:5]])
# Out:
# [[30770 30770]
#  [30075 30232]
#  [29923 30075]
#  [29787 29923]
#  [29643 29787]]
# ['s' 'o' 'o' 'pbd' 'po']

# %%
data_path = r"C:\Users\lhauptmann\Code\WristPPG2\data\dataset"
for participant in os.listdir(data_path):
    participant_path = os.path.join(data_path, participant)
    for file in os.listdir(participant_path):
        if "corrected" in file or not file.endswith(".hdf5"):
            continue
        print(file)
        
        with h5py.File(os.path.join(participant_path, file), 'r+') as f:
            data_dict = f
            num_corrected = 0
            for key in data_dict.keys():
                
                if key == "data":
                    continue
                start_time = f[key]["start_time"][()]
                end_time = f[key]["end_time"][()]
                label = key.split("_")[0]
                #print(f"{key}: {start_time} - {end_time} {label}")
                
                if end_time == start_time and str(label) == "o":
                    num_corrected += 1
                    end_time = start_time + 150/112.3
                    f[key]["end_time"][()] = end_time
        print(f"Corrected {num_corrected} labels")
# Out:
# participant_alex_1.hdf5
# Corrected 233 labels
# participant_alex_2.hdf5
# Corrected 322 labels
# participant_alex_3.hdf5
# Corrected 128 labels
# participant_alex_4.hdf5
# Corrected 120 labels
# participant_amran_1.hdf5
# Corrected 0 labels
# participant_amran_2.hdf5
# Corrected 0 labels
# participant_amran_3.hdf5
# Corrected 63 labels
# participant_amran_4.hdf5
# Corrected 0 labels
# participant_annamalai_1.hdf5
# Corrected 0 labels
# participant_annamalai_2.hdf5
# Corrected 0 labels
# participant_annamalai_3.hdf5
# Corrected 0 labels
# participant_annamalai_4.hdf5
# Corrected 0 labels
# participant_antonia_1.hdf5
# Corrected 0 labels
# participant_antonia_2.hdf5
# Corrected 0 labels
# participant_antonia_4.hdf5
# Corrected 0 labels
# participant_anusha_1.hdf5
# Corrected 105 labels
# participant_anusha_2.hdf5
# Corrected 322 labels
# participant_anusha_3.hdf5
# Corrected 124 labels
# participant_anusha_4.hdf5
# Corrected 146 labels
# participant_ariane_1.hdf5
# Corrected 0 labels
# participant_ariane_2.hdf5
# Corrected 0 labels
# participant_ariane_3.hdf5
# Corrected 0 labels
# participant_ariane_4.hdf5
# Corrected 0 labels
# participant_athena_1.hdf5
# Corrected 0 labels
# participant_athena_2.hdf5
# Corrected 0 labels
# participant_athena_3.hdf5
# Corrected 0 labels
# participant_athena_4.hdf5
# Corrected 0 labels
# participant_ben_1.hdf5
# Corrected 0 labels
# participant_ben_2.hdf5
# Corrected 0 labels
# participant_ben_3.hdf5
# Corrected 0 labels
# participant_berken_1.hdf5
# Corrected 0 labels
# participant_berken_2.hdf5
# Corrected 0 labels
# participant_berken_3.hdf5
# Corrected 0 labels
# participant_berken_4.hdf5
# Corrected 0 labels
# participant_bjoern_1.hdf5
# Corrected 0 labels
# participant_bjoern_2.hdf5
# Corrected 0 labels
# participant_bjoern_3.hdf5
# Corrected 0 labels
# participant_bjoern_4.hdf5
# Corrected 0 labels
# participant_blaise_1.hdf5
# Corrected 267 labels
# participant_blaise_2.hdf5
# Corrected 195 labels
# participant_blaise_3.hdf5
# Corrected 109 labels
# participant_blaise_4.hdf5
# Corrected 129 labels
# participant_bo_1.hdf5
# Corrected 236 labels
# participant_bo_2.hdf5
# Corrected 252 labels
# participant_bo_3.hdf5
# Corrected 258 labels
# participant_bo_4.hdf5
# Corrected 226 labels
# participant_caroline_1.hdf5
# Corrected 0 labels
# participant_caroline_2.hdf5
# Corrected 0 labels
# participant_caroline_3.hdf5
# Corrected 0 labels
# participant_caroline_4.hdf5
# Corrected 0 labels
# participant_daria_1.hdf5
# Corrected 0 labels
# participant_daria_2.hdf5
# Corrected 0 labels
# participant_daria_3.hdf5
# Corrected 0 labels
# participant_daria_4.hdf5
# Corrected 0 labels
# participant_david_1.hdf5
# Corrected 0 labels
# participant_david_2.hdf5
# Corrected 0 labels
# participant_david_3.hdf5
# Corrected 0 labels
# participant_david_4.hdf5
# Corrected 0 labels
# participant_davud_1.hdf5
# Corrected 0 labels
# participant_davud_2.hdf5
# Corrected 0 labels
# participant_davud_3.hdf5
# Corrected 0 labels
# participant_davud_4.hdf5
# Corrected 0 labels
# participant_dominik_1.hdf5
# Corrected 0 labels
# participant_dominik_2.hdf5
# Corrected 0 labels
# participant_dominik_3.hdf5
# Corrected 0 labels
# participant_duan_2.hdf5
# Corrected 0 labels
# participant_duan_3.hdf5
# Corrected 0 labels
# participant_duan_4.hdf5
# Corrected 0 labels
# participant_elsa_1.hdf5
# Corrected 0 labels
# participant_elsa_2.hdf5
# Corrected 0 labels
# participant_elsa_3.hdf5
# Corrected 0 labels
# participant_elsa_4.hdf5
# Corrected 0 labels
# participant_eren_1.hdf5
# Corrected 123 labels
# participant_eren_2.hdf5
# Corrected 107 labels
# participant_eren_3.hdf5
# Corrected 102 labels
# participant_eren_4.hdf5
# Corrected 86 labels
# participant_felix_1.hdf5
# Corrected 0 labels
# participant_felix_2.hdf5
# Corrected 0 labels
# participant_felix_3.hdf5
# Corrected 0 labels
# participant_felix_4.hdf5
# Corrected 0 labels
# participant_frawa_1.hdf5
# Corrected 157 labels
# participant_frawa_2.hdf5
# Corrected 182 labels
# participant_frawa_3.hdf5
# Corrected 107 labels
# participant_frawa_4.hdf5
# Corrected 153 labels
# participant_gonzalo_1.hdf5
# Corrected 0 labels
# participant_gonzalo_2.hdf5
# Corrected 0 labels
# participant_gonzalo_3.hdf5
# Corrected 177 labels
# participant_gonzalo_4.hdf5
# Corrected 171 labels
# participant_hannah_1.hdf5
# Corrected 0 labels
# participant_hannah_2.hdf5
# Corrected 0 labels
# participant_hannah_3.hdf5
# Corrected 0 labels
# participant_hannah_4.hdf5
# Corrected 0 labels
# participant_Heiyi_2.hdf5
# Corrected 0 labels
# participant_Heiyi_3.hdf5
# Corrected 0 labels
# participant_Heiyi_4.hdf5
# Corrected 0 labels
# participant_ida_1.hdf5
# Corrected 0 labels
# participant_ida_2.hdf5
# Corrected 0 labels
# participant_ida_3.hdf5
# Corrected 0 labels
# participant_ida_4.hdf5
# Corrected 0 labels
# participant_ivan_1.hdf5
# Corrected 0 labels
# participant_ivan_2.hdf5
# Corrected 0 labels
# participant_ivan_3.hdf5
# Corrected 0 labels
# participant_ivan_4.hdf5
# Corrected 0 labels
# participant_jack_1.hdf5
# Corrected 0 labels
# participant_jack_2.hdf5
# Corrected 0 labels
# participant_jack_3.hdf5
# Corrected 0 labels
# participant_jack_4.hdf5
# Corrected 0 labels
# participant_jakob_1.hdf5
# Corrected 0 labels
# participant_jakob_2.hdf5
# Corrected 0 labels
# participant_jakob_3.hdf5
# Corrected 0 labels
# participant_jakob_4.hdf5
# Corrected 0 labels
# participant_jamie_1.hdf5
# Corrected 0 labels
# participant_jamie_2.hdf5
# Corrected 0 labels
# participant_jamie_3.hdf5
# Corrected 0 labels
# participant_jamie_4.hdf5
# Corrected 0 labels
# participant_jilian_1.hdf5
# Corrected 0 labels
# participant_jilian_2.hdf5
# Corrected 0 labels
# participant_jilian_3.hdf5
# Corrected 0 labels
# participant_jilian_4.hdf5
# Corrected 0 labels
# participant_jorge_1.hdf5
# Corrected 0 labels
# participant_jorge_2.hdf5
# Corrected 0 labels
# participant_jorge_3.hdf5
# Corrected 0 labels
# participant_jorge_4.hdf5
# Corrected 0 labels
# participant_julia_1.hdf5
# Corrected 0 labels
# participant_julia_2.hdf5
# Corrected 0 labels
# participant_julia_3.hdf5
# Corrected 0 labels
# participant_julia_4.hdf5
# Corrected 0 labels
# participant_kenna_1.hdf5
# Corrected 0 labels
# participant_kenna_2.hdf5
# Corrected 0 labels
# participant_kenna_3.hdf5
# Corrected 0 labels
# participant_kenna_4.hdf5
# Corrected 0 labels
# participant_lars_1.hdf5
# Corrected 0 labels
# participant_lars_2.hdf5
# Corrected 0 labels
# participant_lars_3.hdf5
# Corrected 0 labels
# participant_lars_4.hdf5
# Corrected 0 labels
# participant_lilian_1.hdf5
# Corrected 188 labels
# participant_lilian_2.hdf5
# Corrected 137 labels
# participant_lilian_3.hdf5
# Corrected 144 labels
# participant_lilian_4.hdf5
# Corrected 138 labels
# participant_liuxin_1.hdf5
# Corrected 0 labels
# participant_liuxin_2.hdf5
# Corrected 0 labels
# participant_liuxin_3.hdf5
# Corrected 0 labels
# participant_louisa_1.hdf5
# Corrected 0 labels
# participant_louisa_2.hdf5
# Corrected 0 labels
# participant_louisa_3.hdf5
# Corrected 0 labels
# participant_louisa_4.hdf5
# Corrected 0 labels
# participant_maedeh_1.hdf5
# Corrected 186 labels
# participant_maedeh_2.hdf5
# Corrected 190 labels
# participant_maedeh_3.hdf5
# Corrected 0 labels
# participant_maedeh_4.hdf5
# Corrected 0 labels
# participant_martina_1.hdf5
# Corrected 0 labels
# participant_martina_2.hdf5
# Corrected 0 labels
# participant_martina_3.hdf5
# Corrected 0 labels
# participant_matteo_1.hdf5
# Corrected 0 labels
# participant_matteo_2.hdf5
# Corrected 0 labels
# participant_matteo_3.hdf5
# Corrected 0 labels
# participant_matteo_4.hdf5
# Corrected 0 labels
# participant_matthias_1.hdf5
# Corrected 0 labels
# participant_matthias_2.hdf5
# Corrected 0 labels
# participant_matthias_3.hdf5
# Corrected 0 labels
# participant_matthias_4.hdf5
# Corrected 0 labels
# participant_max_1.hdf5
# Corrected 0 labels
# participant_max_2.hdf5
# Corrected 0 labels
# participant_max_3.hdf5
# Corrected 0 labels
# participant_max_4.hdf5
# Corrected 0 labels
# participant_mia_2.hdf5
# Corrected 0 labels
# participant_mia_3.hdf5
# Corrected 0 labels
# participant_mia_4.hdf5
# Corrected 0 labels
# participant_michel_1.hdf5
# Corrected 0 labels
# participant_michel_2.hdf5
# Corrected 0 labels
# participant_michel_3.hdf5
# Corrected 0 labels
# participant_michel_4.hdf5
# Corrected 0 labels
# participant_miro_1.hdf5
# Corrected 0 labels
# participant_miro_2.hdf5
# Corrected 0 labels
# participant_miro_3.hdf5
# Corrected 0 labels
# participant_miro_4.hdf5
# Corrected 0 labels
# participant_miyuki_1.hdf5
# Corrected 147 labels
# participant_miyuki_2.hdf5
# Corrected 126 labels
# participant_miyuki_3.hdf5
# Corrected 99 labels
# participant_miyuki_4.hdf5
# Corrected 211 labels
# participant_molly_1.hdf5
# Corrected 0 labels
# participant_molly_2.hdf5
# Corrected 0 labels
# participant_molly_3.hdf5
# Corrected 0 labels
# participant_molly_4.hdf5
# Corrected 0 labels
# participant_moritz_1.hdf5
# Corrected 171 labels
# participant_moritz_2.hdf5
# Corrected 132 labels
# participant_moritz_3.hdf5
# Corrected 83 labels
# participant_moritz_4.hdf5
# Corrected 84 labels
# participant_nicole_1.hdf5
# Corrected 0 labels
# participant_nicole_2.hdf5
# Corrected 0 labels
# participant_nicole_3.hdf5
# Corrected 0 labels
# participant_nicole_4.hdf5
# Corrected 0 labels
# participant_oscar_1.hdf5
# Corrected 324 labels
# participant_oscar_2.hdf5
# Corrected 309 labels
# participant_oscar_3.hdf5
# Corrected 404 labels
# participant_oscar_4.hdf5
# Corrected 76 labels
# participant_pam_1.hdf5
# Corrected 186 labels
# participant_pam_2.hdf5
# Corrected 324 labels
# participant_pam_3.hdf5
# Corrected 119 labels
# participant_paul_1.hdf5
# Corrected 0 labels
# participant_paul_2.hdf5
# Corrected 0 labels
# participant_paul_4.hdf5
# Corrected 0 labels
# participant_paula_1.hdf5
# Corrected 0 labels
# participant_paula_2.hdf5
# Corrected 0 labels
# participant_paula_3.hdf5
# Corrected 0 labels
# participant_paula_4.hdf5
# Corrected 0 labels
# participant_rayan_1.hdf5
# Corrected 0 labels
# participant_rayan_2.hdf5
# Corrected 0 labels
# participant_rayan_3.hdf5
# Corrected 0 labels
# participant_rayan_4.hdf5
# Corrected 0 labels
# participant_rolando_1.hdf5
# Corrected 154 labels
# participant_rolando_2.hdf5
# Corrected 181 labels
# participant_rolando_3.hdf5
# Corrected 117 labels
# participant_rolando_4.hdf5
# Corrected 239 labels
# participant_sam_1.hdf5
# Corrected 0 labels
# participant_sam_2.hdf5
# Corrected 0 labels
# participant_sam_3.hdf5
# Corrected 0 labels
# participant_sam_4.hdf5
# Corrected 0 labels
# participant_sel_1.hdf5
# Corrected 0 labels
# participant_sel_2.hdf5
# Corrected 0 labels
# participant_sel_3.hdf5
# Corrected 0 labels
# participant_sel_4.hdf5
# Corrected 0 labels
# participant_sol_1.hdf5
# Corrected 0 labels
# participant_sol_2.hdf5
# Corrected 0 labels
# participant_sol_3.hdf5
# Corrected 0 labels
# participant_sol_4.hdf5
# Corrected 0 labels
# participant_svenja_1.hdf5
# Corrected 0 labels
# participant_svenja_2.hdf5
# Corrected 0 labels
# participant_svenja_3.hdf5
# Corrected 0 labels
# participant_svenja_4.hdf5
# Corrected 0 labels
# participant_tobias_1.hdf5
# Corrected 0 labels
# participant_tobias_2.hdf5
# Corrected 0 labels
# participant_tobias_3.hdf5
# Corrected 0 labels
# participant_tobias_4.hdf5
# Corrected 0 labels
# participant_xintong_1.hdf5
# Corrected 0 labels
# participant_xintong_2.hdf5
# Corrected 0 labels
# participant_xintong_3.hdf5
# Corrected 0 labels
# participant_xintong_4.hdf5
# Corrected 0 labels
# participant_yang_1.hdf5
# Corrected 0 labels
# participant_yang_2.hdf5
# Corrected 0 labels
# participant_yang_3.hdf5
# Corrected 0 labels
# participant_yang_4.hdf5
# Corrected 0 labels
# participant_yichi_1.hdf5
# Corrected 0 labels
# participant_yichi_2.hdf5
# Corrected 0 labels
# participant_yichi_3.hdf5
# Corrected 0 labels
# participant_yichi_4.hdf5
# Corrected 0 labels
# participant_ying_1.hdf5
# Corrected 0 labels
# participant_ying_2.hdf5
# Corrected 0 labels
# participant_ying_3.hdf5
# Corrected 0 labels
# participant_ying_4.hdf5
# Corrected 0 labels
# participant_Zhipeng_1.hdf5
# Corrected 0 labels
# participant_Zhipeng_2.hdf5
# Corrected 0 labels
# participant_Zhipeng_3.hdf5
# Corrected 0 labels
# participant_Zhipeng_4.hdf5
# Corrected 0 labels
